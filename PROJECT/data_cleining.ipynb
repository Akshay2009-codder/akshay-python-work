# %%
# importing naccesary libraries
import pandas as pd
import numpy as np

# %%
# reading the dataset
data = pd.read_csv("employees.csv")
print(data)

# %%
# chacking missing values
missing_value = data.isnull().sum()
print(missing_value)
